# %% [markdown]
# # Product diagnostics
# The tested SQL foundation generates funnel, cohort, and lifecycle readouts.

# %%
from src.data.generate_marketplace import generate_marketplace
from src.data.build_features import build_feature_frame
features = build_feature_frame(generate_marketplace(2025, 1000))
features.head()
