# %% [markdown]
# # Randomized experiment analysis
# Use the offline smoke data or a locally downloaded Criteo file.

# %%
from src.experimentation.criteo import smoke_criteo
from src.experimentation.estimation import estimate_itt
estimate_itt(smoke_criteo(), 'conversion', expected_probability=.85, fail_on_srm=False)
