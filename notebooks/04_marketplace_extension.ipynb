# %% [markdown]
# # Marketplace extension
# Capacity-aware targeting and geo validation are simulated and explicitly labeled.

# %%
from src.marketplace.geo_experiment import geo_experiment_design
geo_experiment_design(10, .2, 100)
